# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Matplot

# %%
# %matplotlib inline

# %%
warnings.filterwarnings("ignore")

# %%
x = [-3,5,7]

# %%
y = [10,2,5]

# %%
fig = plt.figure(figsize=(15,3))

plt.plot(x,y)
plt.xlim(-5,10)
plt.ylim(0,10)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("line chart")
plt.suptitle("XYZ", size = 15, y = 1.02)
# Out:
# Text(0.5, 1.02, 'XYZ')

# %%
df = pd.read_csv("PATH/Q7.csv")

# %%
plt.scatter(df.Points,df.Score)

# %%
plt.hist(df.Points,facecolor = "peru", edgecolor = "blue", bins = 5)
# Out:
# (array([11.,  4., 10.,  6.,  1.]),
#  array([2.76 , 3.194, 3.628, 4.062, 4.496, 4.93 ]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(df.Score, vert = True)
plt.xlabel("Score")
# Out:
# Text(0.5, 0, 'Score')

# %%
plt.violinplot(df.Points)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x268eec938b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x268eec937f0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x268eec93df0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x268eeca8160>}

# %% [markdown]
# ## Seaborn

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#strip plot
sns.stripplot(y = "tip", data = tips, jitter = True)
plt.ylabel("tip $")
plt.show()

# %%
#grouping with strip plots
sns.stripplot(x="day",y="tip",data=tips,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
#swarm plot
sns.swarmplot(x="day",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x="day",y="tip",data=tips,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
#changing orientation
sns.swarmplot(x="tip",y="day",data=tips,hue="sex",orient = "h")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
#Box plot and Violin plot
sns.boxplot(x="day",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.subplot(1,2,1)
sns.boxplot(x="day",y="tip",data=tips)
plt.subplot(1,2,2)
sns.violinplot(x="day",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.subplot(1,2,1)
sns.violinplot(x="day",y="tip",data=tips,inner=None,color="lightgray")
sns.stripplot(x="day",y="tip",data=tips,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# ## Bivariate visualisation

# %%
#Joint plot
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde")

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="sex")
